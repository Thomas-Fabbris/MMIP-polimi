# %% [markdown]
# <a href="https://colab.research.google.com/github/Thomas-Fabbris/MMIP-polimi/blob/main/lecture_15_IRLS_MOD_l1Denoising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage.io import imread
from google.colab import drive
import numpy as np
from scipy.io import loadmat
from matplotlib import pyplot as plt
import time

# %%
drive.mount('/content/drive', force_remount=True)
ROOT_FOLDER = '/content/drive/MyDrive/MMIP/data'
# Out:
# Mounted at /content/drive

# %% [markdown]
# IRLS Algorithm
# --------------
# Define the problem parameters

# %%
A = np.array([[1, 3], [3, 1]])
b = np.array([-1, 2])

lmbda = 0.5

# %% [markdown]
# The function to be minimized is $\frac{1}{2}\|Ax-b\|_2^2 + \lambda \|x\|_1$

# %%
def f(x): return 0.5 * np.sum((A @ x - b) ** 2) + lmbda * np.sum(np.abs(x))

# derivative of f from matrix calculus


def df(x): return A.T @ (A @ x) - A.T @ b

# %% [markdown]
# Plot the function

# %%
# this function has been prepared only for the visualization sake, no need to go through this but it renders some nice
# graphics :)
def F(r1, r2): return 0.5 * ((r1 * A[0, 0] + r2 * A[0, 1] - b[0]) ** 2 + (
    r1 * A[1, 0] + r2 * A[1, 1] - b[1]) ** 2) + lmbda * (np.abs(r1) + np.abs(r2))


xx, yy = np.meshgrid(np.arange(-10, 10, 1), np.arange(-10, 10, 1))

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(xx, yy, F(xx, yy), edgecolor=[
                0, 0, 1], alpha=0.5, facecolor=[0, 1, 1])

# %% [markdown]
# Set the parameters

# %%
MAX_ITER = 1e3
TOL_DIST_X = 1e-10

# %% [markdown]
# Initialization: test different inizializations, the function is convex, you always converge to the same solution

# %%
x0 = np.array([5, -10])

# initialization
all_x = [x0]
distanceX = 1e10  # stopping criteria
cnt = 0
delta = 1e-6

# %% [markdown]
# Main loop

# %%
while cnt < MAX_ITER and distanceX > TOL_DIST_X:
    x = all_x[-1]

    # compute the weight matrix
    W = np.diag(1/np.abs(x))

    # solve the weighted regularized LS system
    x_current = np.linalg.solve((A.T @ A + lmbda * W), A.T @ b)

    distanceX = np.linalg.norm(x_current - x)

    # store the estimate
    all_x.append(x_current)

    cnt = cnt + 1

# %% [markdown]
# Plot all the estimates

# %%
# plot the new estimate
xxplot = [x[0] for x in all_x]
yyplot = [x[1] for x in all_x]
zzplot = F(np.array(xxplot), np.array(yyplot))

fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.plot_surface(xx, yy, F(xx, yy), edgecolor=[
                0, 0, 1], alpha=0.5, facecolor=[0, 1, 1])
ax.plot3D(xxplot, yyplot, zzplot, 'r-o')

# %%
print(f'nr of iteration of IRLS (before stopping criteria met): {cnt}\n')
print(f'Solution of IRLS: [{x_current[0]:.4f}, {x_current[1]:.4f}]\n')
print(f'Value of the functional: {f(x_current):.4f}\n')
# Out:
# nr of iteration of IRLS (before stopping criteria met): 14
#
# Solution of IRLS: [0.7500, -0.5000]
#
# Value of the functional: 0.6875

# %% [markdown]
# MOD dictionary learning
# -----------------------
# Useful function for plot the 2D DCT dictionary

# %%
def get_dictionary_img(D):
    M, N = D.shape
    p = int(round(np.sqrt(M)))
    nnn = int(np.ceil(np.sqrt(N)))
    bound = 2
    img = np.ones((nnn*p+bound*(nnn-1), nnn*p+bound*(nnn-1)))
    for i in range(N):
        m = np.mod(i, nnn)
        n = int((i-m)/nnn)
        m = m * p + bound * m
        n = n * p + bound * n
        atom = D[:, i].reshape((p, p))
        if atom.min() < atom.max():
            atom = (atom - atom.min()) / (atom.max() - atom.min())
        img[m: m + p, n: n + p] = atom

    return img

# %% [markdown]
# Define a function to perform the sparse coding using your favorite algorithm (IRLS, FISTA or ISTA)

# %%
def IRLS(s, D, lmbda, x0=None):
    if x0 is None:
        x0 = np.linalg.lstsq(D, s, rcond=None)[0]

    x_current = x0
    distanceX = 1e10  # stopping criteria
    cnt = 0
    delta = 1e-6
    MAX_ITER = 1e3
    TOL_DIST_X = 1e-10

    while cnt < MAX_ITER and distanceX > TOL_DIST_X:
        x = x_current

        # compute the weight matrix
        W = np.diag(1/(np.abs(x) + delta))

        # solve the weighted regularized LS system
        x_current = np.linalg.solve((D.T @ D + lmbda * W), D.T @ s)

        distanceX = np.linalg.norm(x_current - x)
        cnt = cnt + 1

# %% [markdown]
# Load the image and rescale it in [0,1]

# %%
img = imread((f'{ROOT_FOLDER}/barbara.png')) / 255
imsz = img.shape

# %% [markdown]
# Set the parameters

# %%
# patch size
p = 8

# number of elements in the patchfrom skimage.io import imread
M = p ** 2

# number of columns in the dictionary
N = 96

# extract the random patches from the noisy image
npatch = 1000

# only few MOD iterations are needed for a good dictionary
max_iter = 10

lmbda = 0.1

# %% [markdown]
# Extract $npatch$ random patches from the image

# %%
S = np.zeros((M, npatch))
# Extract random patches
for k in range(npatch):
    i = np.random.randint(0, imsz[0] - p + 1)
    j = np.random.randint(0, imsz[1] - p + 1)
    S[:, k] = img[i:i + p, j:j + p].flatten()

# %% [markdown]
# Initialize the dictionary randomly and the normalize the columns

# %%
D = np.random.rand(M, N)

# %% [markdown]
# Initialize a matrix for the coefficients of all the patches

# %%
X = np.zeros((N, npatch))

# %% [markdown]
# Main loop

# %%
x = np.ones_like(D.shape[1])
for iter in range(max_iter):

    # perform the sparse coding for all the patches in S
    for n in range(npatch):
        s = S[:, n]
        x = IRLS(s, D, lmbda,x)
        X[:, n] = x

    # MOD update
    D = S @ X.T @ np.linalg.inv(X @ X.T)

    # normalize the column
    D = 1/np.linalg.norm(D, axis=1) * D
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4161/690158500.py in <cell line: 0>()
#       5     for n in range(npatch):
#       6         s = S[:, n]
# ----> 7         x = IRLS(s, D, lmbda,x)
#       8         X[:, n] = x
#       9
#
# /tmp/ipykernel_4161/4108207157.py in IRLS(s, D, lmbda, x0)
#      14
#      15         # compute the weight matrix
# ---> 16         W = np.diag(1/np.abs(x))
#      17
#      18         # solve the weighted regularized LS system
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_twodim_base_impl.py in diag(v, k)
#     309         return diagonal(v, k)
#     310     else:
# --> 311         raise ValueError("Input must be 1- or 2-d.")
#     312
#     313
#
# ValueError: Input must be 1- or 2-d.

# %% [markdown]
# Show the dictionary

# %%
img_dict = get_dictionary_img(D)
plt.figure()
plt.imshow(img_dict, cmap='gray')

# %% [markdown]
# Denoising via $\ell^1$ sparse coding (you can use either the dictionary learned by KSVD or MOD)
# ------------------------------------
# Set the noise level and add the noise to the original image

# %%
sigma_noise = 20/255
noisy_img = img + np.random.normal(size=imsz) * sigma_noise

# %% [markdown]
# Compute the psnr of the noisy input

# %%
# psnr_noisy =

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].imshow(img, cmap='gray')
ax[0].set_title('Original image')

ax[1].imshow(noisy_img, cmap='gray')
ax[1].set_title(f'Noisy image, PSNR = {psnr_noisy:.2f}')

# %% [markdown]
# Load a pretrained dictionary $D$

# %%
D = loadmat(f'{rootfolder}/data/dict_nat_img.mat')['D']

# show the dictionary
D_img = get_dictionary_img(D)
plt.figure(figsize=(10, 10))
plt.imshow(D_img, cmap='gray')

# %%
# initialize the estimated image
img_hat_FISTA = np.zeros_like(img)

# initialize the weight matrix
weights_FISTA = np.zeros_like(img)

# set the threshold
tau = 2.2
lmbda = tau * sigma_noise

# define the step (=p for non overlapping paches)
STEP = 4  # STEP = 1 might be very time consuming, start with larger STEP

# %% [markdown]
# Operate patchwise, use FISTA to perform the Sparse Coding step.

# %%
for i in range(0, imsz[0] - p + 1, STEP):
    for j in range(0, imsz[1] - p + 1, STEP):
        # extrach the patch with the top left corner at pixel (ii, jj)
        # s =

        # store and subtract the mean

        # perform the sparse coding of the patch s to compute the coefficients vector x with FISTA
        # x =

        # perform the reconstruction
        # s_hat =

        w = 1

        # add back the mean
        # s_hat =

        # put the denoised patch into the estimated image using uniform weights
        # update img_hat_FISTA

        # store the weight of the current patch in the weight matrix
        # update weights_FISTA

# %% [markdown]
# Normalize the estimated image with the computed weights

# %%
# img_hat_FISTA =

# %% [markdown]
# Compute the psnr of the estimated image

# %%
psnr_hat_FISTA = 10*np.log10(1 / np.mean((img - img_hat_FISTA) ** 2))
plt.figure(figsize=(10, 10))
plt.imshow(img_hat_FISTA, cmap='gray')
plt.title(f'Estimated Image,\nPSNR = {psnr_hat_FISTA:.2f}')

# %% [markdown]
# Repeat the same process, but this time replace FISTA with IRLS and compare the denoised images.

# %%
# initialize the estimated image
img_hat_IRLS = np.zeros_like(img)

# initialize the weight matrix
weights_IRLS = np.zeros_like(img)

# %%
for i in range(0, imsz[0] - p + 1, STEP):
    for j in range(0, imsz[1] - p + 1, STEP):
        # extrach the patch with the top left corner at pixel (ii, jj)
        # s =

        # store and subtract the mean

        # perform the sparse coding of the patch s to compute the coefficients vector x with IRLS
        # x =

        # perform the reconstruction
        # s_hat =

        w = 1

        # add back the mean
        # s_hat =

        # put the denoised patch into the estimated image using uniform weights
        # update img_hat_IRLS

        # store the weight of the current patch in the weight matrix
        # update weights_IRLS

# %%
# img_hat_IRLS =

# %%
psnr_hat_IRLS = 10*np.log10(1 / np.mean((img - img_hat_IRLS) ** 2))
plt.figure(figsize=(10, 10))
plt.imshow(img_hat_IRLS, cmap='gray')
plt.title(f'Estimated Image,\nPSNR = {psnr_hat_IRLS:.2f}')
